# %%
import numpy as np
import pandas as pd
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data=pd.read_csv("/content/Restaurant_3.csv")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#            DATE   TIME  INVOICE_NO                   ITEM  QUANTITY  RATE  \
# 0    01-10-2023  12.08           3              CHAPPATHI         3    18
# 1    01-10-2023  12.15           4         CHILLI CHICKEN         1   100
# 2    01-10-2023  12.15           4       CHICKEN BIRIYANI         2   110
# 3    01-10-2023  12.15           5                PAROTTA         2    18
# 4    01-10-2023  12.36           7                 KALAKI         1    15
# ..          ...    ...         ...                    ...       ...   ...
# 608  02-10-2023  22.12        9159              GOLI SODA         3    30
# 609  02-10-2023  22.12        9159        GHEE PODI ROAST         1    60
# 610  02-10-2023  22.12        9159   CHICKEN PALLIPALAYAM         1   120
# 611  02-10-2023  22.12        9159  PEPPER CHICKEN MASALA         1   130
# 612  02-10-2023  22.12        9159        MUSHROOM CHILLI         1    80
#
#      SUB_TOTAL  AMOUNT DAY   CATEGORY  PERSON
# 0           54    54.0  1_  MAIN DISH     1.0
# 1          100   320.0  1_    STARTER     2.0
# 2          220     NaN  1_  MAIN DISH     NaN
# 3           36    36.0  1_  MAIN DISH     1.0
# 4           15    69.0  1_    STARTER     1.0
# ..         ...     ...  ..        ...     ...
# 608         90   728.0  2_    BEVRAGE     NaN
# 609         60     NaN  2_  MAIN DISH     NaN
# 610        120     NaN  2_      GRAVY     NaN
# 611        130     NaN  2_      GRAVY     NaN
# 612         80     NaN  2_    STARTER     NaN
#
# [613 rows x 11 columns]

# %%
data.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          DATE   TIME  INVOICE_NO              ITEM  QUANTITY  RATE  SUB_TOTAL  \
# 0  01-10-2023  12.08           3         CHAPPATHI         3    18         54
# 1  01-10-2023  12.15           4    CHILLI CHICKEN         1   100        100
# 2  01-10-2023  12.15           4  CHICKEN BIRIYANI         2   110        220
# 3  01-10-2023  12.15           5           PAROTTA         2    18         36
# 4  01-10-2023  12.36           7            KALAKI         1    15         15
#
#    AMOUNT DAY   CATEGORY  PERSON
# 0    54.0  1_  MAIN DISH     1.0
# 1   320.0  1_    STARTER     2.0
# 2     NaN  1_  MAIN DISH     NaN
# 3    36.0  1_  MAIN DISH     1.0
# 4    69.0  1_    STARTER     1.0

# %%
data.tail()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#            DATE   TIME  INVOICE_NO                   ITEM  QUANTITY  RATE  \
# 608  02-10-2023  22.12        9159              GOLI SODA         3    30
# 609  02-10-2023  22.12        9159        GHEE PODI ROAST         1    60
# 610  02-10-2023  22.12        9159   CHICKEN PALLIPALAYAM         1   120
# 611  02-10-2023  22.12        9159  PEPPER CHICKEN MASALA         1   130
# 612  02-10-2023  22.12        9159        MUSHROOM CHILLI         1    80
#
#      SUB_TOTAL  AMOUNT DAY   CATEGORY  PERSON
# 608         90   728.0  2_    BEVRAGE     NaN
# 609         60     NaN  2_  MAIN DISH     NaN
# 610        120     NaN  2_      GRAVY     NaN
# 611        130     NaN  2_      GRAVY     NaN
# 612         80     NaN  2_    STARTER     NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 613 entries, 0 to 612
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   DATE        613 non-null    object
#  1   TIME        613 non-null    float64
#  2   INVOICE_NO  613 non-null    int64
#  3   ITEM        613 non-null    object
#  4   QUANTITY    613 non-null    int64
#  5   RATE        613 non-null    int64
#  6   SUB_TOTAL   613 non-null    int64
#  7   AMOUNT      243 non-null    float64
#  8   DAY         613 non-null    object
#  9   CATEGORY    606 non-null    object
#  10  PERSON      243 non-null    float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 52.8+ KB
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data.describe()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#              TIME   INVOICE_NO    QUANTITY        RATE   SUB_TOTAL  \
# count  613.000000   613.000000  613.000000  613.000000  613.000000
# mean    18.219250   686.773246    1.750408   57.918434   77.970636
# std      3.414651  2126.360182    2.189850   46.909974   66.920662
# min     12.080000     1.000000    1.000000   10.000000   10.000000
# 25%     15.010000    55.000000    1.000000   18.000000   36.000000
# 50%     19.420000   102.000000    1.000000   35.000000   70.000000
# 75%     21.270000   154.000000    2.000000  100.000000  100.000000
# max     23.400000  9159.000000   44.000000  530.000000  792.000000
#
#            AMOUNT      PERSON
# count  243.000000  243.000000
# mean   196.691358    1.901235
# std    150.282652    1.316817
# min     35.000000    1.000000
# 25%     89.500000    1.000000
# 50%    151.000000    2.000000
# 75%    268.000000    2.000000
# max    792.000000   15.000000

# %%
data.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (613, 11)

# %%
x=data['ITEM']
x
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0                  CHAPPATHI
# 1             CHILLI CHICKEN
# 2           CHICKEN BIRIYANI
# 3                    PAROTTA
# 4                     KALAKI
#                ...
# 608                GOLI SODA
# 609          GHEE PODI ROAST
# 610     CHICKEN PALLIPALAYAM
# 611    PEPPER CHICKEN MASALA
# 612          MUSHROOM CHILLI
# Name: ITEM, Length: 613, dtype: object

# %%
from mlxtend.preprocessing import TransactionEncoder
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
te=TransactionEncoder()
te_ary=te.fit(x).transform(x)
df=pd.DataFrame(te_ary,columns=te.columns_)
df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                 (      )      5      6      A      B      C      D      E  \
# 0    False  False  False  False  False   True  False   True  False  False
# 1     True  False  False  False  False  False  False   True  False   True
# 2     True  False  False  False  False   True   True   True  False   True
# 3    False  False  False  False  False   True  False  False  False  False
# 4    False  False  False  False  False   True  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 608   True  False  False  False  False   True  False  False   True  False
# 609   True  False  False  False  False   True  False  False   True   True
# 610   True  False  False  False  False   True  False   True  False   True
# 611   True  False  False  False  False   True  False   True  False   True
# 612   True  False  False  False  False  False  False   True  False  False
#
#      ...      O      P      R      S      T      U      V      W      Y      Z
# 0    ...  False   True  False  False   True  False  False  False  False  False
# 1    ...  False  False  False  False  False  False  False  False  False  False
# 2    ...  False  False   True  False  False  False  False  False   True  False
# 3    ...   True   True   True  False   True  False  False  False  False  False
# 4    ...  False  False  False  False  False  False  False  False  False  False
# ..   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 608  ...   True  False  False   True  False  False  False  False  False  False
# 609  ...   True   True   True   True   True  False  False  False  False  False
# 610  ...  False   True  False  False  False  False  False  False   True  False
# 611  ...  False   True   True   True  False  False  False  False  False  False
# 612  ...   True  False   True   True  False   True  False  False  False  False
#
# [613 rows x 29 columns]

# %%
from mlxtend.frequent_patterns import fpgrowth
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
fpgrowth(df,min_support=0.3)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#      support     itemsets
# 0   0.719413          (5)
# 1   0.601958         (13)
# 2   0.399674         (23)
# 3   0.378467          (7)
# 4   0.371941         (20)
# 5   0.334421         (12)
# 6   0.598695          (0)
# 7   0.429038          (9)
# 8   0.404568         (18)
# 9   0.399674         (16)
# 10  0.306688         (15)
# 11  0.580750         (21)
# 12  0.575856         (19)
# 13  0.396411      (5, 13)
# 14  0.329527      (5, 23)
# 15  0.349103     (19, 23)
# 16  0.365416      (13, 7)
# 17  0.334421       (0, 7)
# 18  0.326264   (0, 13, 7)
# 19  0.352365      (20, 5)
# 20  0.318108      (12, 7)
# 21  0.313214     (12, 13)
# 22  0.309951  (12, 13, 7)
# 23  0.504078      (0, 13)
# 24  0.388254       (0, 5)
# 25  0.303426   (0, 13, 5)
# 26  0.365416       (0, 9)
# 27  0.401305      (0, 18)
# 28  0.376835     (18, 13)
# 29  0.316476     (18, 21)
# 30  0.373573  (0, 18, 13)
# 31  0.316476  (0, 18, 21)
# 32  0.308320     (16, 13)
# 33  0.306688     (13, 15)
# 34  0.451876      (5, 21)
# 35  0.407830      (0, 21)
# 36  0.347471     (13, 21)
# 37  0.347471  (0, 13, 21)
# 38  0.420881      (19, 5)
# 39  0.321370     (19, 21)

# %%
fpgrowth(df,min_support=0.1,use_colnames=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       support      itemsets
# 0    0.719413           (A)
# 1    0.601958           (I)
# 2    0.399674           (T)
# 3    0.378467           (C)
# 4    0.371941           (P)
# ..        ...           ...
# 800  0.102773     (D, I, E)
# 801  0.102773  (D, I, E,  )
# 802  0.135400     (D, A, S)
# 803  0.135400     (D, O, A)
# 804  0.135400  (D, O, A, S)
#
# [805 rows x 2 columns]
